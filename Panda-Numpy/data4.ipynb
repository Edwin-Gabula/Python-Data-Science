# %% [markdown]
# ##### Reading data from an csv file
# ##### Reading data from xlx and xlsx files

# %%
import pandas as pd
import numpy as np

data = pd.read_csv(
    "full.csv"
)

list(data.columns)
# Out:
# ['Study Programme 2026-2027',
#  'Study level',
#  'Branch of Science',
#  'Albania',
#  'Algeria',
#  'Angola',
#  'Argentina',
#  'Armenia',
#  'Azerbaijan',
#  'Bahrain',
#  'Bangladesh',
#  'Belarus',
#  'Belize',
#  'Bosnia and Herzegovina',
#  'Botswana',
#  'Brazil',
#  'Brunei',
#  'Burkina Faso',
#  'Burundi',
#  'Cambodia',
#  'Cape Verde',
#  'Chad',
#  'Chile',
#  'China',
#  'Colombia',
#  'Costa Rica',
#  'Cuba',
#  'Democratic Republic of the Congo',
#  'Dominican Republic',
#  'Ecuador',
#  'Egypt',
#  'El Salvador',
#  'Equatorial Guinea',
#  'Eritrea',
#  'Ethiopia',
#  'Gambia',
#  'Georgia',
#  'Ghana',
#  'Guinea-Bissau',
#  'Honduras',
#  'India',
#  'Indonesia',
#  'Iran',
#  'Iraq',
#  'Israel',
#  'Japan',
#  'Jordan',
#  'Kazakhstan',
#  'Kenya',
#  'Kosovo',
#  'Kurdistan',
#  'Kyrgyzstan',
#  'Laos',
#  'Lebanon',
#  'Liberia',
#  'Libya',
#  'Madagascar',
#  'Malaysia',
#  'Maldives',
#  'Mali',
#  'Marshall Islands',
#  'Mauritius',
#  'Mexico',
# ...
