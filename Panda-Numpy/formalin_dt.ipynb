# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas import Series, DataFrame

data = pd.read_excel(
    "data_formalin.xlsx"
)

data.isnull().sum()

data
# Out:
#          MARKET  CONCENTARATION(mg/pg)  FOMALIN RESIDULES(mg/kg)  \
# 0        KAZO 1                   9.53                      0.43
# 1        KAZO 2                  10.63                      1.53
# 2   WANDEGEYA 1                   7.20                     -1.90
# 3   WANDEGEYA 2                   7.20                     -1.90
# 4     KUTANO 1                    9.33                      0.23
# 5      KUTANO 2                   8.11                     -0.99
# 6      KUTANO 3                   9.31                      0.21
# 7      KUTANO 4                  10.87                      1.77
# 8      KUTANO 5                  10.89                      1.79
# 9      KUTANO 6                   8.63                     -0.47
# 10    KALERWE 1                  12.16                      3.06
# 11   KALERWE  2                   8.47                     -0.63
# 12    KALERWE 3                   7.13                     -1.97
# ...
