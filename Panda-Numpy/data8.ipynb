# %%
import pandas as pd
import numpy as np

data = pd.read_excel(
    "facility.xlsx"
)

data
# Out:
#     Unnamed: 0                                         Unnamed: 1  \
# 0          NaN  STOCK AVAILABILITY\nHEALTH FACILITY CODE………………...
# 1          NaN                                                NaN
# 2          NaN                       Before USAID fund withdrawal
# 3          NaN                                                NaN
# 4          NaN                                                  1
# 5          NaN                                                  2
# 6          NaN                                                  3
# 7          NaN                                                  4
# 8          NaN                                                  5
# 9          NaN                                                  6
# 10         NaN                                                  7
# 11         NaN                                                  8
# 12         NaN                                                NaN
# ...
