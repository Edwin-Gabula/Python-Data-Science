# %%
#exporting data from excel sheets

import pandas as pd
import numpy as np

data = pd.read_excel(
    "full-degree.xlsx"
)

data
# Out:
#                              Study Programme 2026-2027 Study level  \
# 0             Preparatory Course in Hungarian Language         NON
# 1                               Commerce and Marketing          BA
# 2                               Finance and Accounting          BA
# 3                   International Economy and Business          MA
# 4                     International Business Economics          BA
# ..                                                 ...         ...
# 458  Classical Musical Instrumental Performance [Vi...          MA
# 459  Classical Musical Instrumental Performance [Ch...          MA
# 460  Classical Musical Instrumental Performance [Oboa]          MA
# 461  Classical Musical Instrumental Performance [Ce...          MA
# 462                            Sustainable Agriculture          MA
#
#          Branch of Science Albania Algeria Angola Argentina Armenia  \
# 0    Preparatory Programme     yes     yes    yes       yes     yes
# ...
