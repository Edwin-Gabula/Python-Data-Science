# %%
#creating a dataframe

import pandas as pd
import numpy as np

patients = pd.DataFrame(
    {
        "Patient ID": [101,102,103,104],
        "Name": ["David", "Owen", "Kellen", "Elton"],
        "Age": [34,67,4,19],
        "Gender": ["Male", "Female", "Female", "Male"],
        "Diagnosis": ["Hypertension", "Diabetes", "Malaria", "Asthma"],
        "Medicines": ["Amlodipine", "Metformin", "Coartem", "Salbutamol"]
    }
)

patients.iloc[2]
# Out:
# Patient ID        103
# Name           Kellen
# Age                 4
# Gender         Female
# Diagnosis     Malaria
# Medicines     Coartem
# Name: 2, dtype: object

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_excel(
    "user_data.xlsx"
)
df.head(25)
# Out:
#                     Name                         Email  Age          City  \
# 0         Jennifer Gomez           qpeters@example.net   70      San Jose
# 1            Todd Galvan          rachel02@example.com   79     Charlotte
# 2          Cheryl Cannon    parkerjennifer@example.org   77    Washington
# 3       Barbara Mcdonald     lucerobradley@example.org   56    Fort Worth
# 4              April Lee           corey92@example.com   26   San Antonio
# 5   Dr. Matthew Peterson   harringtonkerry@example.org   55     San Diego
# 6         Tracy Sullivan        burnsjames@example.net   32        Austin
# 7            Eric Garcia    josepherickson@example.com   43    Washington
# 8              Noah Wood    castillojeremy@example.net   68        Denver
# 9          Travis Newman         jasmine70@example.org   45       Chicago
# 10          Amy Phillips  reynoldscheyenne@example.net   35       Seattle
# 11            Jay Moreno            sara85@example.com   25  Indianapolis
# 12           Mary Rogers     jeffreymartin@example.com   20      New York
# 13         Valerie Mckay        marknguyen@example.org   70     San Diego
# 14         Megan Oconnor    courtneywalker@example.com   67      Columbus
# 15           Peter Smith          nicole69@example.org   53       Chicago
# 16          Diana Rivers          andrew81@example.com   29    Fort Worth
# 17       Peter Mcpherson          mjohnson@example.com   56       Chicago
# 18        Roberta Tucker          rmorales@example.org   60    Washington
# 19       Meagan Jennings         heather55@example.net   66  Indianapolis
# 20         William Smith            beth89@example.org   19      New York
# 21          Jeffrey Hall           qgarcia@example.net   46     San Diego
# 22         Shannon Jones            wmyers@example.com   68    Fort Worth
# 23         Jessica Avila          justin30@example.org   37     San Diego
# 24            Kayla Sims            glloyd@example.com   68    Fort Worth
#
#     Purchase_Amount
# 0            219.76
# 1            165.34
# 2            230.83
# 3            292.18
# 4            411.51
# 5            491.03
# 6             55.84
# 7            324.66
# 8            269.76
# 9            496.74
# 10           312.11
# 11           316.26
# 12           394.14
# 13           329.42
# 14           284.06
# 15           314.47
# 16           160.02
# 17           484.51
# 18           165.84
# 19           427.39
# 20            11.09
# 21           448.09
# 22           334.52
# 23           429.48
# 24           226.83
