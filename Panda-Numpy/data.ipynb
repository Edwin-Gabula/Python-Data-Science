# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_xlsx(
    "/Users/hyper-realism/Desktop/Python\ DS/user_data.xlsx "
)

df
# Out:
# <>:6: SyntaxWarning: invalid escape sequence '\ '
# <>:6: SyntaxWarning: invalid escape sequence '\ '
# /var/folders/6r/bcnrhk750dv79yqgg2x743v80000gn/T/ipykernel_2891/736398711.py:6: SyntaxWarning: invalid escape sequence '\ '
#   "/Users/hyper-realism/Desktop/Python\ DS/user_data.xlsx "
# /var/folders/6r/bcnrhk750dv79yqgg2x743v80000gn/T/ipykernel_2891/736398711.py:6: SyntaxWarning: invalid escape sequence '\ '
#   "/Users/hyper-realism/Desktop/Python\ DS/user_data.xlsx "
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 5
#       2 import pandas as pd
#       3 import matplotlib.pyplot as plt
# ----> 5 df = pd.read_xlsx(
#       6     "/Users/hyper-realism/Desktop/Python\ DS/user_data.xlsx "
#       7 )
#       9 df
#
# AttributeError: module 'pandas' has no attribute 'read_xlsx'
